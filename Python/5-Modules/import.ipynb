# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi

print(sqrt(144))
print(pi)
# Out:
# 12.0
# 3.141592653589793

# %%
from package.my_package import addition

print(addition(4,5))
# Out:
# 9

# %%
from package import my_package

my_package.addition(4,5)
# Out:
# 9
