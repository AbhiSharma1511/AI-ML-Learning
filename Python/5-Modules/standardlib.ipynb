# %%
import math

print(math.sqrt(188))
print(math.pi)
# Out:
# 13.711309200802088
# 3.141592653589793

# %%
## random

import random
print(random.randint(1,100))
print(random.choice(['apple','orange', 'banana']))
# Out:
# 19
# banana

# %%
## file and directory access

import os

os.getcwd()
# Out:
# 'e:\\CodingPlayground\\AIML\\Python\\5-Modules'

# %%
os.mkdir('test.html')
a = 1

# %%
## high level operation on file and collection of files
import shutil

shutil.copyfile('source.txt', f'destination{a}.txt')
a += 1

# %%
## data serialization
import json
data = {
    'name': 'John',
    'age': 30,
    'city': 'New York'
}

print(type(data))
json_str = json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# <class 'dict'>
# {"name": "John", "age": 30, "city": "New York"}
# <class 'str'>
# {'name': 'John', 'age': 30, 'city': 'New York'}
# <class 'dict'>

# %%
### csv files
import csv

with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age', 'City'])
    writer.writerow(['Alice', 28, 'Los Angeles'])
    writer.writerow(['Bob', 34, 'Chicago'])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '28', 'Los Angeles']
# ['Bob', '34', 'Chicago']

# %%
## datetime

from datetime import datetime, timedelta
now = datetime.now()
print(now.__format__('%Y-%m-%d %H:%M:%S'))

yesterday = now - timedelta(days=3)
print(yesterday)

tomorrow = now + timedelta(days=1)
print(tomorrow.__format__('%Y / %m / %d %H:%M:%S'))
# Out:
# 2026-01-12 07:28:58
# 2026-01-09 07:28:58.411561
# 2026 / 01 / 13 07:28:58

# %%
# time

import time
print(time.time())

time.sleep(3)
print("3 seconds later")
# Out:
# 1768183222.7654812
# 3 seconds later

# %%
#regular expression

import re

pattern  = r'\d+'

text = 'There are 123  677 apples'

match = re.search(pattern, text)
print(match.group())
# Out:
# 123
