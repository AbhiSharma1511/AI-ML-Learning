# %%
print("Hello World")
# Out:
# Hello World

# %%
## python use the indentation for the exceution of the blocks
age = 32
if(age):
    print("Age is exist")
else:

    print("Age is not exist")
# Out:
# Age is exist

# %%
# this is single line of comment
print("Single line comment")
# Out:
# Single line comment

# %%
# line continuation  =  '\'
total  = 1+5+6+8+4+9+3+\
8+9+6

print(total)
# Out:
# 59

# %%
# multiple statemnt in the single line
x= 5; y=10; z = 7
print(x)
# Out:
# 5

# %%
# variable assignment

age = 32
name='Krish'

print(type(age))
type(name)
# Out:
# <class 'int'>
# str

# %%
#type inference
var = 10
print(type(var))
var = 'abhi'
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# name error
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # name error
# ----> 2 a = b
#
# NameError: name 'b' is not defined

# %%
# code example of indentation
if True:
    print('Correct indentation' )
    if False:
        print("If inside the if")
    print("This will print")
print("Outside the if block")
# Out:
# Correct indentation
# This will print
# Outside the if block
